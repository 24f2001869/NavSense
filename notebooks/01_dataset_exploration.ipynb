# %% [markdown]
# # SIH26168 — 01: IO-VNBD Dataset Exploration & Inspection
#
# **Objective**: Verify the execution environment and inspect the raw benchmark dataset (`IO-VNBD`) without running any navigation, AI, or filtering algorithms.
#
# ### Verification Goals:
# 1. Confirm Python interpreter points to `.venv`
# 2. Inspect directory hierarchy of `data/raw/IO-VNBD/`
# 3. Inspect fields and data types of Smartphone (`S-*.csv`) and Vehicle (`V-*.csv`) recordings
# 4. Determine sensor units and nominal sampling frequencies

# %%
import sys
print("Python Executable:", sys.executable)
print("Python Version:   ", sys.version)

# %% [markdown]
# ### Step 1: Run Full Dataset Inspection Script
# We invoke the modular inspection script `src.data.inspect_dataset` to parse the complete tree and inspect sample recordings.

# %%
import os
from pathlib import Path
import pandas as pd
import numpy as np

# Ensure project root is in sys.path
PROJECT_ROOT = Path("..").resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.data.inspect_dataset import walk_dataset_tree, inspect_csv_files, analyze_sample_file

DATASET_ROOT = PROJECT_ROOT / "data" / "raw" / "IO-VNBD"
print("Dataset root:", DATASET_ROOT)
walk_dataset_tree(DATASET_ROOT, max_depth=3)

# %% [markdown]
# ### Step 2: Discover and Categorize CSV Streams

# %%
s_files, v_files, other_files = inspect_csv_files(DATASET_ROOT)
print(f"Found {len(s_files)} smartphone files and {len(v_files)} vehicle files.")

# %% [markdown]
# ### Step 3: Inspect First Smartphone Recording (`S-*.csv`)

# %%
if s_files:
    analyze_sample_file(s_files[0], label="SMARTPHONE SENSOR STREAM")

# %% [markdown]
# ### Step 4: Inspect First Vehicle Reference Recording (`V-*.csv`)

# %%
if v_files:
    analyze_sample_file(v_files[0], label="VEHICLE REFERENCE / ODOMETRY STREAM")
