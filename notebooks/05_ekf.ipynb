# %% [markdown]
# # SIH26168 — Step 5: Extended Kalman Filter (EKF) Baseline
#
# In this notebook, we evaluate the classical loosely-coupled INS/GNSS Extended Kalman Filter:
# - 7-State navigation filter: $[p_E, p_N, v_E, v_N, \psi, b_a, b_\omega]^T$
# - 10 Hz IMU Prediction step
# - 1 Hz GNSS Correction step
# - Seamless handling of a 30-second GNSS blackout (t=50s to t=80s) and rapid reacquisition upon signal return

# %%
import sys
from pathlib import Path
from IPython.display import Image

repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.fusion.evaluate_ekf import run_ekf_simulation

metrics = run_ekf_simulation('Vta02', duration_s=150, outage_start=50.0, outage_dur=30.0)
Image(filename=str(repo_root / 'results' / 'figures' / 'Vta02_ekf_outage_simulation.png'))
