# %% [markdown]
# # SIH26168 — Step 7: AI + EKF Fusion & Architecture Comparison
#
# In this notebook, we evaluate our complete physics-AI hybrid navigation engine against the baseline classical architectures during a simulated GNSS tunnel/blackout on an unseen journey (`Vta04`):
# 1. **Pure IMU Dead Reckoning**: Quadratic/cubic divergence (>500% drift).
# 2. **Baseline EKF (Blind)**: Free IMU propagation without velocity aiding during outage (~93% drift).
# 3. **AI Speed Dead Reckoning**: Gyro heading + AI forward speed dead reckoning.
# 4. **AI + EKF Fusion with NHC (Proposed)**: Full hybrid fusion achieving over **90% error reduction** compared to raw inertial mechanization.
#
# We also compute the complete SIH Target Evaluation Matrix across varying outage intervals (5s, 10s, 30s, 60s).

# %%
import sys
from pathlib import Path
import pandas as pd
from IPython.display import Image

repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.fusion.benchmark_fusion import run_four_mode_comparison, generate_sih_benchmark_matrix

# %%
# Run 4-Mode Benchmark Comparison
df_comp = run_four_mode_comparison('Vta04', outage_start=25.0, outage_dur=30.0)
df_comp

# %%
# Display Trajectory Plot
Image(filename=str(repo_root / 'results' / 'figures' / 'Vta04_architecture_comparison.png'))

# %%
# Display the SIH Benchmark Matrix
df_matrix = pd.read_csv(repo_root / 'results' / 'benchmark_matrix.csv')
df_matrix
