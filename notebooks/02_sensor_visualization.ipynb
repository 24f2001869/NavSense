# %% [markdown]
# # SIH26168 — Step 2: Sensor Stream Visualization & Ground Truth Mapping
#
# In this notebook, we visualize the synchronized sensor streams from the IO-VNBD benchmark dataset:
# - 3-axis Smartphone Accelerometer, Gyroscope, and Magnetometer
# - True Vehicle Forward Velocity (VBOX CAN-bus ground truth at 10 Hz) vs Smartphone GPS Speed
# - 2D Geodetic Ground Truth Route Map

# %%
import sys
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Ensure project root is in sys.path
repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.data.loader import load_trip
from src.data.visualize_sensors import plot_sensor_timeseries, plot_2d_route_map

# %%
# Load Trip Vta02
df_phone, df_veh = load_trip('Vta02')
print(f"Trip Vta02 loaded: {len(df_phone)} rows ({df_phone['time_s'].iloc[-1]:.1f} s duration)")
print(f"Max vehicle ground truth speed: {df_veh['veh_speed_kmh'].max():.1f} km/h ({df_veh['veh_speed_ms'].max():.2f} m/s)")

# %%
# Plot Sensor Timeseries for initial 120 seconds
plot_sensor_timeseries(df_phone, df_veh, trip_name='Vta02', duration_s=120)

from IPython.display import Image
Image(filename=str(repo_root / 'results' / 'figures' / 'Vta02_sensor_timeseries.png'))

# %%
# Plot 2D Ground Truth Route Map
plot_2d_route_map(df_veh, trip_name='Vta02')
Image(filename=str(repo_root / 'results' / 'figures' / 'Vta02_2d_route_map.png'))
