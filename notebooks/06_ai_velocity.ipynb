# %% [markdown]
# # SIH26168 — Step 6: AI Forward Velocity Estimation
#
# In this notebook, we evaluate AI-based direct vehicle forward velocity prediction from smartphone IMU signals:
# - Multi-domain feature extraction across sliding 1.0-second windows (10 samples @ 10 Hz)
# - Strict journey separation: trained on `Vta02`, tested on unseen journey `Vta04` (zero data leakage)
# - Comparative modeling: Ridge Regression, HistGradientBoosting, and Random Forest
# - Statistical vibration filtering and causal EMA smoothing to achieve an average error < 2 m/s (< 7 km/h)

# %%
import sys
from pathlib import Path
from IPython.display import Image

repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.ml.train_velocity import train_and_evaluate

results = train_and_evaluate(['Vta02'], ['Vta04'])
Image(filename=str(repo_root / 'results' / 'figures' / 'ai_velocity_prediction.png'))
