# %% [markdown]
# # SIH26168 — Step 4: Pure IMU Dead Reckoning & Failure Quantification
#
# In this notebook, we execute pure unconstrained inertial double-integration on smartphone IMU data:
# - Double integration: $\mathbf{a} \to \mathbf{v} \to \mathbf{p}$
# - Direct visualization of quadratic and cubic error divergence
# - Quantification of baseline failure: RMSE, Final Position Error (FPE), and SIH Drift Percentage

# %%
import sys
from pathlib import Path
from IPython.display import Image

repo_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

from src.navigation.evaluate_dead_reckoning import evaluate_dead_reckoning

metrics = evaluate_dead_reckoning('Vta02', duration_s=120)
Image(filename=str(repo_root / 'results' / 'figures' / 'Vta02_pure_dead_reckoning_drift.png'))
